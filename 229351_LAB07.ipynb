# %% [markdown]
# <a href="https://colab.research.google.com/github/PinkOrangeSapphire/223351/blob/main/229351_LAB07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ปฏิบัติการครั้งที่ 6 กระบวนวิชา 229351 Statistical Learning for Data Science
#
# คำชี้แจง
#
# ให้เริ่มทำปฏิบัติการจาก colab notebook ที่กำหนดให้ จากนั้น share แล้วส่ง link มาใน mango.cmu.ac.th

# %% [markdown]
# ดาวน์โหลดข้อมูลรถยนต์ชนิดต่างใน link ข้างล่างนี้
# https://donlapark.pages.dev/229351/data/Auto.csv
# หรือรันโค้ดข้างล่าง

# %%
# import module ที่ต้องใช้
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# StatsModels
# !pip install statsmodels --quiet
import statsmodels.api as sm
import statsmodels.formula.api as smf

# Download the file
# !wget https://donlapark.pages.dev/229351/data/Auto.csv
# Out:
# --2025-08-20 08:17:34--  https://donlapark.pages.dev/229351/data/Auto.csv
# Resolving donlapark.pages.dev (donlapark.pages.dev)... 188.114.96.0, 188.114.97.0, 2a06:98c1:3121::3, ...
# Connecting to donlapark.pages.dev (donlapark.pages.dev)|188.114.96.0|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18079 (18K) [text/csv]
# Saving to: ‘Auto.csv.7’
#
# Auto.csv.7          100%[===================>]  17.66K  --.-KB/s    in 0s
#
# 2025-08-20 08:17:34 (77.1 MB/s) - ‘Auto.csv.7’ saved [18079/18079]

# %%
# อ่านไฟล์ csv ก่อนเพื่อหา missing values
auto = pd.read_csv('Auto.csv', na_values=["?"])

# ลบแถวที่มี missing values
auto = auto.dropna()

auto = auto.drop(['name', 'origin'],axis=1)

auto.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70

# %% [markdown]
# # Linear model diagnosis

# %%
# simple linear regression on Auto dataset
auto_lr = smf.ols('mpg ~ horsepower ', data=auto).fit()
print(auto_lr.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.606
# Model:                            OLS   Adj. R-squared:                  0.605
# Method:                 Least Squares   F-statistic:                     599.7
# Date:                Wed, 20 Aug 2025   Prob (F-statistic):           7.03e-81
# Time:                        08:17:34   Log-Likelihood:                -1178.7
# No. Observations:                 392   AIC:                             2361.
# Df Residuals:                     390   BIC:                             2369.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     39.9359      0.717     55.660      0.000      38.525      41.347
# horsepower    -0.1578      0.006    -24.489      0.000      -0.171      -0.145
# ==============================================================================
# Omnibus:                       16.432   Durbin-Watson:                   0.920
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               17.305
# Skew:                           0.492   Prob(JB):                     0.000175
# Kurtosis:                       3.299   Cond. No.                         322.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### คำนวณ Residuals $y_i-\hat{y}_i$

# %%
#Fitted values
auto_fitted = auto_lr.predict(auto)

#Residuals
auto_res = auto['mpg']-auto_fitted

print(auto_res)
# Out:
# 0      -1.416046
# 1       1.108520
# 2       1.740849
# 3      -0.259151
# 4      -0.837598
#          ...
# 392     0.638786
# 393    12.272065
# 394     5.323097
# 395     0.533873
# 396     4.007407
# Length: 392, dtype: float64

# %% [markdown]
# ### หรือสามารถดึง predictions และ residuals จากโมเดลได้โดยตรง

# %%
# Fitted values
auto_fitted_ = auto_lr.fittedvalues

# Residuals
auto_res_ = auto_lr.resid

# %% [markdown]
# ### 1. ทดสอบ non-linearity

# %%
plt.scatter(auto_fitted, auto_res)
plt.title('Residuals vs Fitted')
plt.xlabel('Fitted values')
plt.ylabel('Residuals');

# %%
plt.scatter(auto_lr.fittedvalues, auto_lr.resid)
plt.title('Residuals vs Fitted')
plt.xlabel('Fitted values')
plt.ylabel('Residuals');

print(auto_lr.fittedvalues)
# Out:
# 0      19.416046
# 1      13.891480
# 2      16.259151
# 3      16.259151
# 4      17.837598
#          ...
# 392    26.361214
# 393    31.727935
# 394    26.676903
# 395    27.466127
# 396    26.992593
# Length: 392, dtype: float64

# %%
auto_lr2 = smf.ols('mpg ~ horsepower+I(horsepower**2)', data=auto).fit()
print(auto_lr2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.688
# Model:                            OLS   Adj. R-squared:                  0.686
# Method:                 Least Squares   F-statistic:                     428.0
# Date:                Wed, 20 Aug 2025   Prob (F-statistic):           5.40e-99
# Time:                        08:17:35   Log-Likelihood:                -1133.2
# No. Observations:                 392   AIC:                             2272.
# Df Residuals:                     389   BIC:                             2284.
# Df Model:                           2
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             56.9001      1.800     31.604      0.000      53.360      60.440
# horsepower            -0.4662      0.031    -14.978      0.000      -0.527      -0.405
# I(horsepower ** 2)     0.0012      0.000     10.080      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                       16.158   Durbin-Watson:                   1.078
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.662
# Skew:                           0.218   Prob(JB):                     2.20e-07
# Kurtosis:                       4.299   Cond. No.                     1.29e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.29e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
plt.scatter(auto_lr2.fittedvalues, auto_lr2.resid)
plt.title('Residuals vs Fitted')
plt.xlabel('Fitted values')
plt.ylabel('Residuals');

# %% [markdown]
# ### 2. ทดสอบ independence of errors
# 2.1 ตรวจสอบโดยการ plot time vs residuals (ถ้าสามารถทำได้)
#
# 2.2 ตรวจสอบด้วย Durbin-Wutson test
#
# H0: There is no correlation among the residuals.
# H1: The residuals are correlated.
#
# The Durbin-Watson statistic ranges in value from 0
# to 4. A value near 2 indicates non-correlation; a value toward 0 indicates positive
# correlation; a value toward 4 indicates negative correlation.
#
# Reject H0 if d < dL
# Accept H0 if d > dU
#
# Durbin-Watson table: https://www.real-statistics.com/statistics-tables/durbin-watson-table/

# %%
auto_lr2 = smf.ols('mpg ~ horsepower+I(horsepower**2)', data=auto).fit()
print(auto_lr2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.688
# Model:                            OLS   Adj. R-squared:                  0.686
# Method:                 Least Squares   F-statistic:                     428.0
# Date:                Wed, 20 Aug 2025   Prob (F-statistic):           5.40e-99
# Time:                        08:17:35   Log-Likelihood:                -1133.2
# No. Observations:                 392   AIC:                             2272.
# Df Residuals:                     389   BIC:                             2284.
# Df Model:                           2
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             56.9001      1.800     31.604      0.000      53.360      60.440
# horsepower            -0.4662      0.031    -14.978      0.000      -0.527      -0.405
# I(horsepower ** 2)     0.0012      0.000     10.080      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                       16.158   Durbin-Watson:                   1.078
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.662
# Skew:                           0.218   Prob(JB):                     2.20e-07
# Kurtosis:                       4.299   Cond. No.                     1.29e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.29e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### ดูตาราง Durbin-Watson Alpha = .05 n = 350 และ k = 2
#
# ได้ค่า dL = 1.813 dU = 1.836
#
# ดังนั้น Reject H0 -- มี correlation ระหว่าง residuals

# %% [markdown]
# ### 3. ทดสอบ constant variance

# %% [markdown]
# ### ใช้ Breush-Pagan test
#
#
# H0: The residuals are distributed with equal variance
# H1: The residuals are not distributed with equal variance

# %%
import statsmodels.stats.api as sms

name = ["Lagrange multiplier statistic", "p-value", "f-value", "f p-value"]
test = sms.het_breuschpagan(auto_lr2.resid, auto_lr2.model.exog)
pd.DataFrame({'Name':name, 'value':test})
# Out:
#                             Name         value
# 0  Lagrange multiplier statistic  3.452843e+01
# 1                        p-value  3.178682e-08
# 2                        f-value  1.878689e+01
# 3                      f p-value  1.626798e-08

# %% [markdown]
# ### p-value < 0.05 ดังนั้น accept H1

# %%
auto_lr3 = smf.ols('I(np.log(mpg)) ~ horsepower+I(horsepower**2)', data=auto).fit()
print(auto_lr3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         I(np.log(mpg))   R-squared:                       0.732
# Model:                            OLS   Adj. R-squared:                  0.731
# Method:                 Least Squares   F-statistic:                     532.2
# Date:                Wed, 20 Aug 2025   Prob (F-statistic):          4.54e-112
# Time:                        08:17:35   Log-Likelihood:                 125.48
# No. Observations:                 392   AIC:                            -245.0
# Df Residuals:                     389   BIC:                            -233.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              4.4022      0.073     60.639      0.000       4.260       4.545
# horsepower            -0.0171      0.001    -13.632      0.000      -0.020      -0.015
# I(horsepower ** 2)  3.901e-05   4.92e-06      7.925      0.000    2.93e-05    4.87e-05
# ==============================================================================
# Omnibus:                        9.051   Durbin-Watson:                   1.092
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):               13.714
# Skew:                          -0.142   Prob(JB):                      0.00105
# Kurtosis:                       3.871   Cond. No.                     1.29e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.29e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
plt.scatter(auto_lr3.fittedvalues, auto_lr3.resid)
plt.title('Residuals vs Fitted')
plt.xlabel('Fitted values')
plt.ylabel('Residuals');

# %% [markdown]
# ### ลอง Breush-Pagan test อีกครั้ง

# %%
name = ["Lagrange multiplier statistic", "p-value", "f-value", "f p-value"]
test = sms.het_breuschpagan(auto_lr3.resid, auto_lr3.model.exog)
pd.DataFrame({'Name':name, 'value':test})
# Out:
#                             Name     value
# 0  Lagrange multiplier statistic  5.202329
# 1                        p-value  0.074187
# 2                        f-value  2.615975
# 3                      f p-value  0.074382

# %% [markdown]
# ### p-value ฬ 0.05 ดังนั้น accept Hจ

# %% [markdown]
# ### 4., 5. หา outliers และ leverage points

# %%
import statsmodels.graphics.api as smg

smg.influence_plot(auto_lr2, size=10)

#Cook's distance line ที่ระดับ 0.5
p = 1 # จำนวนตัวแปรต้น
x = np.linspace(0.01, 0.1, 50)
plt.plot(x, np.sqrt(0.5*p*(1 - x)/x), color='red', linestyle='dashed')

plt.xlim(0,0.1)
plt.xlabel('Leverage')
plt.ylabel('Standardized residuals')
plt.title('Residuals vs Leverage');

# %% [markdown]
# ### 6. ทดสอบ multicollinearity
#
# ลบตัวแปรที่มีค่า VIF > 10

# %%
print(auto_lr3.model.exog)  # matrix of exogenous variables
# Out:
# [[1.0000e+00 1.3000e+02 1.6900e+04]
#  [1.0000e+00 1.6500e+02 2.7225e+04]
#  [1.0000e+00 1.5000e+02 2.2500e+04]
#  ...
#  [1.0000e+00 8.4000e+01 7.0560e+03]
#  [1.0000e+00 7.9000e+01 6.2410e+03]
#  [1.0000e+00 8.2000e+01 6.7240e+03]]

# %%
print(auto_lr3.model.exog_names)  # names of exogenous variables
# Out:
# ['Intercept', 'horsepower', 'I(horsepower ** 2)']

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif

auto_lr4 = smf.ols('I(np.log(mpg)) ~ cylinders \
                                     + displacement \
                                     + horsepower \
                                     + weight \
                                     + acceleration', data=auto).fit()

exog = auto_lr4.model.exog
exog_names = auto_lr4.model.exog_names

for i in range(1,len(exog_names)):
    print(exog_names[i], vif(exog, i))
# Out:
# cylinders 10.6308702529696
# displacement 19.53506094748836
# horsepower 8.916016566767519
# weight 10.43027112753311
# acceleration 2.609486629126141

# %% [markdown]
# ### Exercise
#
# ดาวน์โหลดข้อมูลรถยนต์ชนิดต่างใน link ข้างล่างนี้
# https://donlapark.pages.dev/229351/data/Carseats.csv
# หรือรันโค้ดข้างล่าง

# %%
# Download the file
# !wget https://donlapark.pages.dev/229351/data/Carseats.csv
# Out:
# --2025-08-20 08:17:36--  https://donlapark.pages.dev/229351/data/Carseats.csv
# Resolving donlapark.pages.dev (donlapark.pages.dev)... 188.114.96.0, 188.114.97.0, 2a06:98c1:3121::3, ...
# Connecting to donlapark.pages.dev (donlapark.pages.dev)|188.114.96.0|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19044 (19K) [text/csv]
# Saving to: ‘Carseats.csv.7’
#
# Carseats.csv.7      100%[===================>]  18.60K  --.-KB/s    in 0s
#
# 2025-08-20 08:17:36 (106 MB/s) - ‘Carseats.csv.7’ saved [19044/19044]

# %% [markdown]
# Sales
#
#     Unit sales (in thousands) at each location
# CompPrice
#
#     Price charged by competitor at each location
# Income
#
#     Community income level (in thousands of dollars)
# Advertising
#
#     Local advertising budget for company at each location (in thousands of dollars)
# Population
#
#     Population size in region (in thousands)
# Price
#
#     Price company charges for car seats at each site
# ShelveLoc
#
#     A factor with levels Bad, Good and Medium indicating the quality of the shelving location for the car seats at each site
# Age
#
#     Average age of the local population
# Education
#
#     Education level at each location
# Urban
#
#     A factor with levels No and Yes to indicate whether the store is in an urban or rural location
# US
#
#     A factor with levels No and Yes to indicate whether the store is in the US or not

# %%
# อ่านไฟล์ csv ก่อนเพื่อหา missing values
carseats = pd.read_csv('Carseats.csv')

carseats.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
# ลบแถวที่มี missing values
carseats = auto.dropna()

# %%
all_predictors = '+'.join(carseats_encoded.columns.drop('Sales')) #ใช้สูตร 'Sales ~' + all_predictors ในการสร้างโมเดล

'Sales ~ ' + all_predictors
# Out:
# 'Sales ~ CompPrice+Income+Advertising+Population+Price+Age+Education+ShelveLoc_Good+ShelveLoc_Medium+Urban_Yes+US_Yes'

# %% [markdown]
# ### Bad = Intercept + other values
# ### Medium = Intercept + other values + ShelveLoc(Med)*1
# ### Good = Intercept + other values + ShelveLoc(Good)*1

# %% [markdown]
# ###จงสร้าง residual plot และ influence plot แล้วตอบคำถามต่อไปนี้
#
# 1. สมมติว่าตัวแปรอื่นมีค่าเท่ากัน โดยเฉลี่ยแล้ว ยอดขายของเบาะรถที่วางบนชั้นที่มีคุณภาพปานกลาง (ShelveLoc (Medium)) กับชั้นที่มีคุณภาพต่ำ (ShelveLoc (Bad)) ต่างกันอย่างไร ต่างกันเท่าไหร่
# 2. สมมติว่าตัวแปรอื่นมีค่าเท่ากัน โดยเฉลี่ยแล้ว ยอดขายของเบาะรถที่วางบนชั้นที่มีคุณภาพดี (ShelveLoc (Good)) กับชั้นที่มีคุณภาพปานกลาง (ShelveLoc (Medium)) ต่างกันอย่างไร ต่างกันเท่าไหร่
# 3. จงตรวจสอบว่าข้อมูลที่ใช้มีความเหมาะสมกับการสร้าง linear regression หรือไม่ โดยพิจารณาสิ่งต่างๆเหล่านี้พร้อมกับให้เหตุผล
#   3.1 Non-linearity
#   3.2 Independence of errors
#   3.3 Constant variance
#   3.4 Outliers
#   3.5 Leverage points
#   3.6 Multicollinearity

# %%
carseats_lr = smf.ols('Sales ~' + all_predictors, data=carseats_encoded).fit()
print(carseats_lr.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.868
# Model:                            OLS   Adj. R-squared:                  0.864
# Method:                 Least Squares   F-statistic:                     231.1
# Date:                Wed, 20 Aug 2025   Prob (F-statistic):          1.00e-162
# Time:                        08:19:47   Log-Likelihood:                -579.95
# No. Observations:                 400   AIC:                             1184.
# Df Residuals:                     388   BIC:                             1232.
# Df Model:                          11
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            5.3099      0.620      8.561      0.000       4.090       6.529
# CompPrice            0.0929      0.004     21.800      0.000       0.085       0.101
# Income               0.0165      0.002      8.726      0.000       0.013       0.020
# Advertising          0.1272      0.011     11.125      0.000       0.105       0.150
# Population        7.788e-05      0.000      0.205      0.838      -0.001       0.001
# Price               -0.0953      0.003    -34.711      0.000      -0.101      -0.090
# Age                 -0.0465      0.003    -14.225      0.000      -0.053      -0.040
# Education           -0.0311      0.020     -1.534      0.126      -0.071       0.009
# ShelveLoc_Good       4.8049      0.157     30.534      0.000       4.495       5.114
# ShelveLoc_Medium     1.9193      0.130     14.808      0.000       1.664       2.174
# Urban_Yes            0.0937      0.116      0.807      0.420      -0.135       0.322
# US_Yes              -0.1985      0.154     -1.289      0.198      -0.501       0.104
# ==============================================================================
# Omnibus:                        1.625   Durbin-Watson:                   2.052
# Prob(Omnibus):                  0.444   Jarque-Bera (JB):                1.544
# Skew:                           0.152   Prob(JB):                        0.462
# Kurtosis:                       3.008   Cond. No.                     4.15e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.15e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Assuming carseats_lr model is already fitted and available

# Calculate the difference between Medium and Bad ShelveLoc
# ShelveLoc_Bad is the baseline (intercept)
medium_bad_diff = carseats_lr.params['ShelveLoc_Medium']
print(f"Difference in sales between Medium and Bad ShelveLoc: {medium_bad_diff:.2f}")

# Calculate the difference between Good and Medium ShelveLoc
good_medium_diff = carseats_lr.params['ShelveLoc_Good'] - carseats_lr.params['ShelveLoc_Medium']
print(f"Difference in sales between Good and Medium ShelveLoc: {good_medium_diff:.2f}")
# Out:
# Difference in sales between Medium and Bad ShelveLoc: 1.92
# Difference in sales between Good and Medium ShelveLoc: 2.89

# %% [markdown]
# คำตอบ:
#
# 1.  **ยอดขายของเบาะรถที่วางบนชั้นที่มีคุณภาพปานกลาง (ShelveLoc (Medium)) กับชั้นที่มีคุณภาพต่ำ (ShelveLoc (Bad))**
#
#    ถ้าค่าสถิติอื่นเหมือนกันหมด ชั้นวางของเกรดปานกลางจะช่วยให้ยอดขายเบาะรถ สูงกว่า ชั้นวางเกรดแย่ โดยเฉลี่ยแล้ว ต่างกันอยู่ประมาณ 1.92 พันชิ้น
#
#   Difference in sales between Medium and Bad ShelveLoc: 1.92
#
# 2.  **ยอดขายของเบาะรถที่วางบนชั้นที่มีคุณภาพดี (ShelveLoc (Good)) กับชั้นที่มีคุณภาพปานกลาง (ShelveLoc (Medium))**
#
#      ถ้าตัวแปรอื่นอื่นเท่ากันหมด ชั้นวางของเกรดดีจะช่วยให้ยอดขาย สูงกว่า ชั้นวางเกรดปานกลาง โดยเฉลี่ยแล้ว ต่างกันอยู่ประมาณ 2.89 พันชิ้น
#
#   Difference in sales between Good and Medium ShelveLoc: 2.89

# %%
# Read the Carseats.csv file
carseats = pd.read_csv('Carseats.csv')

# Remove rows with missing values from the Carseats data
carseats = carseats.dropna()

# Fit a linear regression model using the cleaned carseats DataFrame
carseats_lr = smf.ols('Sales ~ CompPrice+Income+Advertising+Population+Price+ShelveLoc+Age+Education+Urban+US', data=carseats).fit()

# Residual plot
plt.scatter(carseats_lr.fittedvalues, carseats_lr.resid)
plt.title('Residuals vs Fitted')
plt.xlabel('Fitted values')
plt.ylabel('Residuals');
plt.show()

# Influence plot
smg.influence_plot(carseats_lr, size=10)
plt.title('Residuals vs Leverage');
plt.show()

# plot time vs residuals
plt.scatter(carseats_lr.resid.index, carseats_lr.resid)
plt.title('Residuals vs Order of Observation')
plt.xlabel('Order of Observation')
plt.ylabel('Residuals')
plt.show()

print(carseats_lr.summary())

bg_test = sms.acorr_breusch_godfrey(carseats_lr)
print(f"p-value: {bg_test[1]:.4f}")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.873
# Model:                            OLS   Adj. R-squared:                  0.870
# Method:                 Least Squares   F-statistic:                     243.4
# Date:                Wed, 20 Aug 2025   Prob (F-statistic):          1.60e-166
# Time:                        08:44:41   Log-Likelihood:                -568.99
# No. Observations:                 400   AIC:                             1162.
# Df Residuals:                     388   BIC:                             1210.
# Df Model:                          11
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               5.6606      0.603      9.380      0.000       4.474       6.847
# ShelveLoc[T.Good]       4.8502      0.153     31.678      0.000       4.549       5.151
# ShelveLoc[T.Medium]     1.9567      0.126     15.516      0.000       1.709       2.205
# Urban[T.Yes]            0.1229      0.113      1.088      0.277      -0.099       0.345
# US[T.Yes]              -0.1841      0.150     -1.229      0.220      -0.479       0.111
# CompPrice               0.0928      0.004     22.378      0.000       0.085       0.101
# Income                  0.0158      0.002      8.565      0.000       0.012       0.019
# Advertising             0.1231      0.011     11.066      0.000       0.101       0.145
# Population              0.0002      0.000      0.561      0.575      -0.001       0.001
# Price                  -0.0954      0.003    -35.700      0.000      -0.101      -0.090
# Age                    -0.0460      0.003    -14.472      0.000      -0.052      -0.040
# Education              -0.0211      0.020     -1.070      0.285      -0.060       0.018
# ==============================================================================
# Omnibus:                        0.811   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.667   Jarque-Bera (JB):                0.765
# Skew:                           0.107   Prob(JB):                        0.682
# Kurtosis:                       2.994   Cond. No.                     4.15e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.15e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# p-value: 0.9678

# %%
import statsmodels.stats.api as sms

name = ["Lagrange multiplier statistic", "p-value", "f-value", "f p-value"]
test = sms.het_breuschpagan(carseats_lr.resid, carseats_lr.model.exog)
pd.DataFrame({'Name':name, 'value':test})
# Out:
#                             Name     value
# 0  Lagrange multiplier statistic  7.328659
# 1                        p-value  0.771878
# 2                        f-value  0.658316
# 3                      f p-value  0.777857

# %%
import statsmodels.graphics.api as smg

smg.influence_plot(carseats_lr, size=10)

#Cook's distance line ที่ระดับ 0.5
p = 11
x = np.linspace(0.01, 0.1, 50)
plt.plot(x, np.sqrt(0.5*p*(1 - x)/x), color='red', linestyle='dashed')

plt.xlim(0,0.1)
plt.xlabel('Leverage')
plt.ylabel('Standardized residuals')
plt.title('Residuals vs Leverage');

# %%
print(carseats_lr.model.exog)

print(carseats_lr.model.exog_names)

from statsmodels.stats.outliers_influence import variance_inflation_factor as vif

exog = carseats_lr.model.exog
exog_names = carseats_lr.model.exog_names

for i in range(1,len(exog_names)):
    print(exog_names[i], vif(exog, i))

# Calculate the correlation matrix for the encoded DataFrame
correlation_matrix = carseats_encoded.corr()

# Display the correlation matrix
display(correlation_matrix)
# Out:
# [[  1.   0.   0. ... 120.  42.  17.]
#  [  1.   1.   0. ...  83.  65.  10.]
#  [  1.   0.   1. ...  80.  59.  12.]
#  ...
#  [  1.   0.   1. ... 159.  40.  18.]
#  [  1.   0.   0. ...  95.  50.  12.]
#  [  1.   1.   0. ... 120.  49.  16.]]
# ['Intercept', 'ShelveLoc[T.Good]', 'ShelveLoc[T.Medium]', 'Urban[T.Yes]', 'US[T.Yes]', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price', 'Age', 'Education']
# ShelveLoc[T.Good] 1.5114108816547631
# ShelveLoc[T.Medium] 1.5178815057838553
# Urban[T.Yes] 1.0227049034513431
# US[T.Yes] 1.980719638938689
# CompPrice 1.5546180981239017
# Income 1.0247310763870372
# Advertising 2.1031356279376445
# Population 1.1455343200880395
# Price 1.5370677298055464
# Age 1.0210506961242922
# Education 1.0263422999995275
#                      Sales  CompPrice    Income  Advertising  Population  \
# Sales             1.000000   0.063982  0.159665     0.274666    0.047315
# CompPrice         0.063982   1.000000 -0.080653    -0.024199   -0.094707
# Income            0.159665  -0.080653  1.000000     0.058995   -0.007877
# Advertising       0.274666  -0.024199  0.058995     1.000000    0.265652
# Population        0.047315  -0.094707 -0.007877     0.265652    1.000000
# Price            -0.442263   0.584848 -0.056698     0.044537   -0.012144
# Age              -0.233740  -0.100239 -0.004670    -0.004557   -0.042663
# Education        -0.060498   0.025197 -0.056855    -0.033594   -0.106378
# ShelveLoc_Good    0.496089   0.026386 -0.012657     0.056149    0.007789
# ShelveLoc_Medium -0.076671   0.008683 -0.051392    -0.015929   -0.040640
# Urban_Yes        -0.018327   0.066594  0.037967     0.042035   -0.052025
# US_Yes            0.181070   0.016869  0.089601     0.684460    0.060564
#
#                      Price       Age  Education  ShelveLoc_Good  \
# Sales            -0.442263 -0.233740  -0.060498        0.496089
# CompPrice         0.584848 -0.100239   0.025197        0.026386
# Income           -0.056698 -0.004670  -0.056855       -0.012657
# Advertising       0.044537 -0.004557  -0.033594        0.056149
# Population       -0.012144 -0.042663  -0.106378        0.007789
# Price             1.000000 -0.102177   0.011747        0.045854
# Age              -0.102177  1.000000   0.006488       -0.022818
# Education         0.011747  0.006488   1.000000       -0.029188
# ShelveLoc_Good    0.045854 -0.022818  -0.029188        1.000000
# ShelveLoc_Medium -0.006607  0.056613   0.013242       -0.571396
# Urban_Yes         0.047016  0.028479  -0.033094       -0.039197
# US_Yes            0.057861  0.008652  -0.078250        0.078864
#
#                   ShelveLoc_Medium  Urban_Yes    US_Yes
# Sales                    -0.076671  -0.018327  0.181070
# CompPrice                 0.008683   0.066594  0.016869
# Income                   -0.051392   0.037967  0.089601
# Advertising              -0.015929   0.042035  0.684460
# Population               -0.040640  -0.052025  0.060564
# Price                    -0.006607   0.047016  0.057861
# Age                       0.056613   0.028479  0.008652
# Education                 0.013242  -0.033094 -0.078250
# ShelveLoc_Good           -0.571396  -0.039197  0.078864
# ShelveLoc_Medium          1.000000  -0.037391 -0.065656
# Urban_Yes                -0.037391   1.000000  0.047085
# US_Yes                   -0.065656   0.047085  1.000000

# %% [markdown]
# ### โมเดล Linear Regression เหมาะกับข้อมูลนี้ไหม?
#
# มาเช็คกันทีละข้อเลยนะ ว่าโมเดลที่เราทำไปมันโอเคหรือเปล่า:
#
# **3.1 Non-linearity (ความสัมพันธ์ไม่ตรงเป็นเส้นตรง):**
# ดูจากกราฟ **Residuals vs Fitted** ที่เราวาดไป จุดกระจายๆ  ดูค่อนข้างสุ่มๆ รอบๆ เส้นตรงกลาง (เส้นที่ Residuals เป็น 0)
#
# **3.2 Independence of errors (ความคลาดเคลื่อนไม่ขึ้นต่อกัน):**
# ดูที่ค่า **Durbin-Watson statistic** ในตารางสรุปโมเดล  ค่าที่ได้คือ [Insert Durbin-Watson value from summary output] ค่านี้มันใกล้ 2 แสดงว่าความคลาดเคลื่อนของข้อมูลแต่ละตัวไม่ค่อยเกี่ยวข้องกัน ถือว่าโอเค
#
# **3.3 Constant variance (ความแปรปรวนเท่ากัน):**
# กราฟ **Residuals vs Fitted** มันบานออกเป็นรูปกรวย หรือแคบเข้าเป็นรูปกรวย แสดงว่าความแปรปรวนไม่คงที่ (Heteroscedasticity)
#
# **3.4 Outliers (ข้อมูลนอกตอก):**
# กราฟ **Influence plot**  จุดที่อยู่โดดๆ ในแนวดิ่ง (Residuals สูงๆ) คือ Outliers
#
# **3.5 Leverage points (ข้อมูลที่มีอิทธิพล):**
# กราฟ **Influence plot**  จุดที่อยู่ทางขวา (Leverage สูงๆ) คือ Leverage points พวกนี้เป็นข้อมูลที่มีค่าของตัวแปรต้นที่อาจจะสุดโต่งกว่าเพื่อน และอาจมีอิทธิพลต่อเส้นโมเดลเราได้
#
# จากการพล็อตกราฟ ไม่พบค่าที่อยู่เหนือ Cook's distance line
#
# **3.6 Multicollinearity (ตัวแปรต้นเกี่ยวข้องกันเองมากเกินไป)
